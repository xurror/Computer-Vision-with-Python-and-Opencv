# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('../Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
# check For NoneType if path wrong
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('../Computer-Vision-with-Python/DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(fix_img)

# %%
new_img = cv2.resize(fix_img,(700,500))
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (650, 975, 3)

# %%
new_img = cv2.flip(fix_img,1)
plt.imshow(new_img)

# %%
cv2.imwrite('new_puppy.jpg', new_img)
# Out:
# True
